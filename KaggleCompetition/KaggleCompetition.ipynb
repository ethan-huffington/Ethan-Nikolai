# %% [markdown]
# <a href="https://colab.research.google.com/github/ethan-huffington/Ethan-Nikolai/blob/master/KaggleCompetition/KaggleCompetition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##<font color='moccasin'>`IMPORTS & SETUP`</font>

# %%
# !pip install timm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting timm
#   Downloading timm-0.6.7-py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 7.9 MB/s
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from timm) (1.12.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from timm) (0.13.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->timm) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->timm) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->timm) (2.10)
# Installing collected packages: timm
# Successfully installed timm-0.6.7

# %%
import timm

# %%
# import tarfile

# %%
import torch
import numpy as np

# %%
# ! [ -e /content ] && pip install -Uqq fastbook
# import fastbook
# fastbook.setup_book()

# %%
# from fastbook import *

# %% [markdown]
# ##<font color='moccasin'>`DATA IMPORTS`

# %% [markdown]
# ###<font color='salmon'>`SETTING DIRECTORIES`

# %%
# PIL: 'Python Image Library'
from PIL import Image

# File Handling
from pathlib import Path

import os

# %%
DATASETS = "Datasets"
os.makedirs(DATASETS, exist_ok=True)

CALTECH_DATASET = "datasets"
os.makedirs(os.path.join(DATASETS, CALTECH_DATASET), exist_ok=True)



# BASEDIR = "basedir"
# os.makedirs(BASEDIR, exist_ok=True)

# DATASETS = "datasets"
# os.makedirs(os.path.join(BASEDIR, DATASETS), exist_ok=True)

# CALTECH_DATASET = f"{BASEDIR}/{DATASETS}/CalTech101"
# os.makedirs(CALTECH_DATASET, exist_ok=True)

# %%
# Create path object pointing to Oxford IIT dataset location
pets_path = Path('pets/images')

# Create list grabbing from iterating over 
pets_image_paths = list(pets_path.iterdir())

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ###<font color='salmon'>`WITH !gdown`

# %% [markdown]
#     !gdown downloads from an endpoint in my google drive

# %%
# Download CalTech101 Images
# !gdown 1-FPR4vi7FYdFQ4mQG6X1w0dBd6xe_0hv

# Download CalTech101 Labels
# !gdown 1L2YFlAXdvzMJuTsI_1hqM9WsoOWyDtJP

# %%
# Unzip tar.gz files:
# zxf means: gunzip (the 'z' letter) and extract (the 'x' letter) from file (the 'f' letter, and the file name follows).
# !tar zxf /content/101_ObjectCategories.tar.gz
# !tar zxf /content/Annotations.tar

# %%
# Grab 2nd image from path list & open with .open() method
image = Image.open(pets_image_paths[1])

# %%
image

# %%
# # open files
# caltech101_images_zipped = tarfile.open('101_ObjectCategories.tar.gz')
# caltech101_labels_zipped = tarfile.open('Annotations.tar')

# # extract files
# caltech101_images =  caltech101_images.extractall('/content')
# caltech101_images = caltech101_labels.extractall('/content')

# %% [markdown]
# ###<font color='salmon'>`WITH !wget`

# %% [markdown]
# ##<font color='moccasin'>`HEADING`</font>

# %% [markdown]
# ##<font color='moccasin'>`HEADING`</font>

# %% [markdown]
# ##<font color='moccasin'>`HEADING`</font>

# %% [markdown]
# ##<font color='moccasin'>`HEADING`</font>

# %% [markdown]
# ##<font color='moccasin'>`HEADING`</font>
